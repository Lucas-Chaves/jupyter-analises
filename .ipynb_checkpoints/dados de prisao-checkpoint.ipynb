# %%
import requests
import json
import pandas as pd

# %%
#entrar no site do https://portalbnmp.cnj.jus.br/#/pesquisa-peca fazer uma requisiçao e descobrir seu 
#idEstado/idMunicipio e cookie para poder fazer as requests atraves do inspecionar elementos network
idEstado = 26
idMunicipio = 9414
cookie = 'portalbnmp=eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJndWVzdF9wb3J0YWxibm1wIiwiYXV0aCI6IlJPTEVfQU5PTllNT1VTIiwiZXhwIjoxNjAwOTg3NjczfQ.rUOs3QfCG__RJGHarCCr1F0Q3HII4yZdDt8B-fxbBiUJJh9iSH_GX9nblbPRY8yr-0oUX8HEkvdtWbAqWnCHvA'

# %%
payload = {
"buscaOrgaoRecursivo": False, 
"orgaoExpeditor": {}, 
"nomePessoa": "",
"idEstado": idEstado, 
"idMunicipio": idMunicipio}
headers = {'content-type': 'application/json', 
           'cookie': cookie}

r = requests.post('https://portalbnmp.cnj.jus.br/bnmpportal/api/pesquisa-pecas/filter?page=0&size=100000000&sort=',
                  data=json.dumps(payload), headers=headers)

# %%
r = requests.post('https://portalbnmp.cnj.jus.br/bnmpportal/api/pesquisa-pecas/filter?page=0&size=100000&sort=',
                  data=json.dumps(payload),
                  headers=headers
                 )

# %%
dados = json.loads(r.content)
df = pd.DataFrame(dados['content'],columns=['nomePessoa', 
                                            'descricaoStatus',  
                                            'descricaoPeca', 
                                            'descricaoProfissao',
                                            'dataExpedicaoFormatada'] )

# %%
df = df.apply(lambda x: x.astype(str).str.lower())

# %%
df.sample(10)
# Out:
#                      nomePessoa          descricaoStatus      descricaoPeca  \
# 361  raimundo nonato de sa lima  pendente de cumprimento  mandado de prisão
# 575            edvaldo de souza  pendente de cumprimento  mandado de prisão
# 271      clóvis eduardo moreira  pendente de cumprimento  mandado de prisão
# 506     antonio de jesus santos  pendente de cumprimento  mandado de prisão
# 446        ewerton luiz martini  pendente de cumprimento  mandado de prisão
# 466              marcelo angelo  pendente de cumprimento  mandado de prisão
# 17        miguel luis vitoriano  pendente de cumprimento  mandado de prisão
# 165    luiz reinaldo de azevedo  pendente de cumprimento  mandado de prisão
# 78      cícero soares damasceno  pendente de cumprimento  mandado de prisão
# 401        joão da silva amaral  pendente de cumprimento  mandado de prisão
#
#     descricaoProfissao dataExpedicaoFormatada
# 361        carpinteiro             05/06/2017
# 575       desempregado             04/06/2018
# 271      não informado             25/06/2019
# 506      não informado             20/08/2018
# 446      não informado             16/01/2019
# 466      não informado             06/12/2018
# 17       não informado             24/04/2018
# 165        serralheiro             19/04/2016
# 78         comerciante             16/08/2015
# 401      não informado             18/09/2014

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df.groupby('descricaoProfissao')['descricaoProfissao'].count().sort_values(ascending=False)
# Out:
# descricaoProfissao
# não informado                    223
# nan                               95
# desempregado                      76
# ajudante geral                    53
# pedreiro                          32
# servente                          32
# autônomo                          29
# estudante                         25
# vendedor                          23
# comerciante                       18
# pintor                            15
# autonomo                          15
# motorista                         15
# mecânico                          11
# empresário                        10
# vigilante                          8
# eletricista                        8
# sem profissão definida             7
# ajudante de pedreiro               7
# aposentado                         7
# funileiro                          6
# prendas domesticas                 6
# mecanico                           6
# motoboy                            5
# auxiliar de serviços gerais        5
# empresario                         5
# montador                           5
# serralheiro                        4
# gesseiro                           4
# prendas do lar                     4
# porteiro                           4
# lavrador                           4
# carpinteiro                        4
# técnico em raios  x                3
# marceneiro                         3
# domestica                          3
# sem profissao definida             3
# repositor                          3
# balconista                         3
# manicure                           2
# empreiteiro                        2
# diarista                           2
# leiteiro                           2
# metalúrgico                        2
# confeiteiro                        2
# designer                           2
# cabeleireiro                       2
# moto-boy                           2
# cozinheiro                         2
# zelador                            2
# pescador                           2
# acougueiro                         2
# auxiliar de serv gerais            2
# trabalhador rural                  2
# auxiliar de producao               2
# professor                          2
# atendente de lanchonete            2
# pintor de automóveis               2
# padeiro                            2
# babá                               1
# desconhecida                       1
# artesão                            1
# armeiro                            1
# apontador de mao de obra           1
# ajudante de pintor                 1
# analista de sistemas               1
# artífice                           1
# ajudante de padeiro                1
# ajudante de cozinha                1
# ajudante                           1
# encanador                          1
# encanador industrial               1
# artifice                           1
# construtor                         1
# atendente                          1
# corretor de imóveis                1
# copeiro                            1
# auxiliar tec de refrigera          1
# comerciário                        1
# auxiliar administrativo            1
# auxiliar de manutenção             1
# auxiliar de montagem               1
# coletor                            1
# caminhoneiro                       1
# auxiliar de produção               1
# caldeireiro                        1
# engenheiro eletrônico              1
# borracheiro                        1
# encarregado                        1
# grafico                            1
# entregador                         1
# publicitário                       1
# operador de caldeiras              1
# operador de escavadeira            1
# operador de maquinas               1
# operador de torno automático       1
# operador telemarketing             1
# outros                             1
# pensionista                        1
# pintor de automoveis               1
# policial militar                   1
# promotor de vendas                 1
# proprietário                       1
# representante comercial            1
# não informada                      1
# seguranca                          1
# segurança                          1
# servente de pedreiro               1
# servidor publico estadual          1
# soldador                           1
# tapeceiro                          1
# tatuador                           1
# tecnico                            1
# tecnico de eletronica              1
# torneiro mecânico                  1
# vendedor ambulante                 1
# office-boy                         1
# nao informado                      1
# escriturario                       1
# gerente comercial                  1
# estampador                         1
# estoquista                         1
# faxineiro                          1
# feirante                           1
# ferramenteiro                      1
# fiscal                             1
# fotografo                          1
# frentista                          1
# fresador                           1
# garcao                             1
# gerente                            1
# guardador de carros                1
# músico                             1
# industriário                       1
# inspetor                           1
# jardineiro                         1
# lavrador(a)                        1
# mecanico de automovel              1
# mecânico de automóvel              1
# mecânico de manutenção             1
# metalurgico                        1
# montador de automoveis             1
# montador de automóveis             1
# montador de móveis de madeira      1
#                                    1
# Name: descricaoProfissao, dtype: int64
