# %%
import requests
import json
import pandas as pd

# %%
#entrar no site do https://portalbnmp.cnj.jus.br/#/pesquisa-peca fazer uma requisiçao e descobrir seu 
#idEstado/idMunicipio e cookie para poder fazer as requests atraves do inspecionar elementos network
idEstado = 26
idMunicipio = 9414
cookie = 'portalbnmp=eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJndWVzdF9wb3J0YWxibm1wIiwiYXV0aCI6IlJPTEVfQU5PTllNT1VTIiwiZXhwIjoxNjAxMTMzMTgxfQ.XfUAY77OFhLzsYbuuiUmo4_vmqqrI2fy_gLBKNbK-l1KZArck_Yd4NdaPrSxKLPCJmKus0fEvlCINLgSSUeWjg'

# %%
payload = {
"buscaOrgaoRecursivo": False, 
"orgaoExpeditor": {}, 
"nomePessoa": "",
"idEstado": idEstado, 
"idMunicipio": idMunicipio}
headers = {'content-type': 'application/json', 
           'cookie': cookie}

r = requests.post('https://portalbnmp.cnj.jus.br/bnmpportal/api/pesquisa-pecas/filter?page=0&size=100000000&sort=',
                  data=json.dumps(payload), headers=headers)

# %%
r = requests.post('https://portalbnmp.cnj.jus.br/bnmpportal/api/pesquisa-pecas/filter?page=0&size=100000&sort=',
                  data=json.dumps(payload),
                  headers=headers
                 )
r
# Out:
# <Response [200]>

# %%
dados = json.loads(r.content)
df = pd.DataFrame(dados['content'],columns=['nomePessoa', 
                                            'descricaoStatus',  
                                            'descricaoPeca', 
                                            'descricaoProfissao',
                                            'dataExpedicaoFormatada'] )

# %%
df = df.apply(lambda x: x.astype(str).str.lower())

# %%
df.sample(10)
# Out:
#                          nomePessoa          descricaoStatus  \
# 805  elvis david dos santos almeida  pendente de cumprimento
# 701         luciano rodolfo mariano  pendente de cumprimento
# 213             rene gomes de souza  pendente de cumprimento
# 885         reinaldo da silva lopes  pendente de cumprimento
# 117           marcos rogério garcia  pendente de cumprimento
# 131          carlos roberto peixoto  pendente de cumprimento
# 567         renan cordeiro da silva  pendente de cumprimento
# 534                      dixon zuin  pendente de cumprimento
# 28    jefferson dos santos jeronimo  pendente de cumprimento
# 591                  nilson alzemon  pendente de cumprimento
#
#          descricaoPeca     descricaoProfissao dataExpedicaoFormatada
# 805  mandado de prisão          não informado             27/02/2019
# 701  mandado de prisão          não informado             01/10/2019
# 213  mandado de prisão             empresario             21/11/2018
# ...

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df.groupby('descricaoProfissao')['descricaoProfissao'].count().sort_values(ascending=False)
# Out:
# descricaoProfissao
# não informado                    223
# nan                               95
# desempregado                      76
# ajudante geral                    53
# pedreiro                          32
# servente                          32
# autônomo                          29
# estudante                         25
# vendedor                          23
# comerciante                       18
# pintor                            15
# autonomo                          15
# motorista                         15
# mecânico                          11
# empresário                        10
# vigilante                          8
# eletricista                        8
# sem profissão definida             7
# ajudante de pedreiro               7
# aposentado                         7
# funileiro                          6
# prendas domesticas                 6
# mecanico                           6
# motoboy                            5
# auxiliar de serviços gerais        5
# ...
